# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib as plt
data = pd.read_csv("tugas dandi.csv",delimiter=";")
cm = sns.light_palette("gold", as_cmap=True)
data.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_c36e1422_ceb4_11e9_8e09_54424970d42brow0_col0 {
#             background-color:  #ffde2e;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow0_col1 {
#             background-color:  #ffd90f;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow0_col2 {
#             background-color:  #ffd90b;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow0_col3 {
#             background-color:  #ffde30;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow1_col0 {
#             background-color:  #fff6c8;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow1_col1 {
#             background-color:  #ffe65e;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow1_col2 {
#             background-color:  #fff7ca;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow1_col3 {
#             background-color:  #ffe455;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow2_col0 {
#             background-color:  #fffadf;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow2_col1 {
#             background-color:  #fff6c8;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow2_col2 {
#             background-color:  #ffe34c;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow2_col3 {
#             background-color:  #ffee95;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow3_col0 {
#             background-color:  #ffed8c;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow3_col1 {
#             background-color:  #ffe767;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow3_col2 {
#             background-color:  #fff3b3;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow3_col3 {
#             background-color:  #ffe65e;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow4_col0 {
#             background-color:  #fff3b3;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow4_col1 {
#             background-color:  #ffdd24;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow4_col2 {
#             background-color:  #fff09d;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow4_col3 {
#             background-color:  #ffdb1b;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow5_col0 {
#             background-color:  #ffe767;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow5_col1 {
#             background-color:  #fff1a3;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow5_col2 {
#             background-color:  #ffe247;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow5_col3 {
#             background-color:  #ffdb17;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow6_col0 {
#             background-color:  #ffd90b;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow6_col1 {
#             background-color:  #ffd702;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow6_col2 {
#             background-color:  #ffe972;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow6_col3 {
#             background-color:  #fffbe4;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow7_col0 {
#             background-color:  #ffda12;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow7_col1 {
#             background-color:  #fff2ac;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow7_col2 {
#             background-color:  #ffd702;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow7_col3 {
#             background-color:  #fff6c3;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow8_col0 {
#             background-color:  #ffea7c;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow8_col1 {
#             background-color:  #ffe244;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow8_col2 {
#             background-color:  #ffec88;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow8_col3 {
#             background-color:  #fff1a7;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow9_col0 {
#             background-color:  #ffe140;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow9_col1 {
#             background-color:  #fff1a7;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow9_col2 {
#             background-color:  #ffd806;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow9_col3 {
#             background-color:  #ffea78;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow10_col0 {
#             background-color:  #fff09d;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow10_col1 {
#             background-color:  #fffadc;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow10_col2 {
#             background-color:  #ffd90b;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow10_col3 {
#             background-color:  #ffef9a;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow11_col0 {
#             background-color:  #fff09e;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow11_col1 {
#             background-color:  #ffe975;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow11_col2 {
#             background-color:  #ffe55c;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow11_col3 {
#             background-color:  #fff2aa;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow12_col0 {
#             background-color:  #fffbe4;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow12_col1 {
#             background-color:  #fff2af;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow12_col2 {
#             background-color:  #ffe763;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow12_col3 {
#             background-color:  #ffeb7e;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow13_col0 {
#             background-color:  #ffe140;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow13_col1 {
#             background-color:  #fffadf;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow13_col2 {
#             background-color:  #ffe557;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow13_col3 {
#             background-color:  #ffe037;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow14_col0 {
#             background-color:  #fff4ba;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow14_col1 {
#             background-color:  #ffe247;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow14_col2 {
#             background-color:  #ffe557;
#             color:  #000000;
#         }    #T_c36e1422_ceb4_11e9_8e09_54424970d42brow14_col3 {
#             background-color:  #ffef97;

# %%
colum = data.columns.tolist()
for x in colum :
    ds = [x for x in data[x]]
    desc = data[x].describe()
    array = [x for x in desc]
    print("Detail kolom",x)
    print("rata-rata: ",array[1])
    print("Median: ",np.median(np.array(ds)))
    print("Modus: ",stats.mode(ds))
    print("Standard deviasi: ",np.std(ds))
    print("varian: ",stats.variation(ds))
    print("Skewness: ",stats.skew(ds))
    print("Quartil 1: ",array[4])
    print("Quartil 2: ",array[5])
    print("Quartil 3: ",array[6])
    sns.distplot(data[x])
    
    print("\n")
# Out:
# Detail kolom Data 1
# rata-rata:  147.658
# Median:  145.0
# Modus:  ModeResult(mode=array([137]), count=array([11]))
# Standard deviasi:  28.64934617054986
# varian:  0.1940250184246696
# Skewness:  0.11278590541991824
# Quartil 1:  123.0
# Quartil 2:  145.0
# Quartil 3:  172.0
#
#
# Detail kolom Data 2
# rata-rata:  149.208
# Median:  149.0
# Modus:  ModeResult(mode=array([107]), count=array([12]))
# Standard deviasi:  28.108374837403886
# varian:  0.18838383221679728
# Skewness:  0.03351262876952946
# Quartil 1:  125.75
# Quartil 2:  149.0
# Quartil 3:  173.0
#
#
# Detail kolom Data 3
# rata-rata:  150.358
# Median:  148.0
# Modus:  ModeResult(mode=array([196]), count=array([12]))
# Standard deviasi:  29.357892226793123
# varian:  0.19525327702412323
# Skewness:  0.06746158597793682
# Quartil 1:  125.0
# Quartil 2:  148.0
# Quartil 3:  176.25
#
#
# Detail kolom Data 4
# rata-rata:  150.622
# Median:  150.0
# Modus:  ModeResult(mode=array([115]), count=array([10]))
# Standard deviasi:  29.350351207438727
# varian:  0.1948609845005293
# Skewness:  -0.0719405196952213
# Quartil 1:  125.0
# Quartil 2:  150.0
# Quartil 3:  176.0
